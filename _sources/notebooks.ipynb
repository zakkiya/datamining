# %% [markdown]
# # Tugas 1

# %%
# mengimpor paket pandas kemudian diberi nama alias pd
import pandas as pd
url="https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/crop_yield.csv"
c = pd.read_csv(url)

# %%
c
# Out:
#    Fert Water  Yield
# 0     A  High   27.4
# 1     A  High   33.6
# 2     A  High   29.8
# 3     A  High   35.2
# 4     A  High   33.0
# 5     B  High   34.8
# 6     B  High   27.0
# 7     B  High   30.2
# 8     B  High   30.8
# 9     B  High   26.4
# 10    A   Low   32.0
# 11    A   Low   32.2
# 12    A   Low   26.0
# 13    A   Low   33.4
# 14    A   Low   26.4
# 15    B   Low   26.8
# 16    B   Low   23.2
# 17    B   Low   29.4
# 18    B   Low   19.4
# 19    B   Low   23.8

# %%
# menunjukkan beberapa data statistik pada kolom yield
c.describe()
# Out:
#            Yield
# count  20.000000
# mean   29.040000
# std     4.230516
# min    19.400000
# 25%    26.400000
# 50%    29.600000
# 75%    32.400000
# max    35.200000

# %%
import seaborn as sns

# %%
# Menampilkan histogram untuk kolom yield pada data menggunakan seaborn
sns.distplot(c['Yield']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
