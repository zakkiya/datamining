# %% [markdown]
# # K-Means on Iris Datasets

# %% [markdown]
# Menjalankan K-Means pada dataset Iris untuk mengklasifikasikan 3 kelas bunga kita, Iris setosa, Iris versicolor, Iris virginica (kelas kita) menggunakan bunga sepal-length, sepal-width, petal-length dan kelopak-lebar.

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
#the imported dataset does not have the required column names so lets add it
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
irisdata = pd.read_csv(url, names=colnames)

# %% [markdown]
# deskripsi data

# %%
irisdata.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Mengubah nama kelas menjadi kategori numerik untuk analisis

# %%
irisdata['Class'] = pd.Categorical(irisdata["Class"])
irisdata["Class"] = irisdata["Class"].cat.codes

# %% [markdown]
# menyiapkan kumpulan data

# %%
X = irisdata.values[:, 0:4]
y = irisdata.values[:, 4]

# %%
from sklearn.cluster import KMeans

# Number of clusters
kmeans = KMeans(n_clusters=3)
# Fitting the input data
kmeans = kmeans.fit(X)
# Getting the cluster labels
labels = kmeans.predict(X)
# Centroid values
centroids = kmeans.cluster_centers_

# %% [markdown]
# Memeriksa akurasi pengelompokan program

# %%
from sklearn.metrics import classification_report

target_names = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

print(classification_report(irisdata['Class'],kmeans.labels_,target_names=target_names))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.00      0.00      0.00        50
# Iris-versicolor       0.00      0.00      0.00        50
#  Iris-virginica       0.95      0.72      0.82        50
#
#        accuracy                           0.24       150
#       macro avg       0.32      0.24      0.27       150
#    weighted avg       0.32      0.24      0.27       150

# %% [markdown]
# *Anda dapat melihat dalam laporan klasifikasi bahwa, 91% dari data diprediksi secara akurat. Itu cukup bagus untuk algoritma yang tidak diawasi.*
