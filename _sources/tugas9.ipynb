# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([103.71079058])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
import pandas as pd
data = {'X': x, 
        'Y' : y}
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                          X          Y
# 0     [0.5685658793547118]   7.834609
# 1    [-0.6052817268567794] -12.623946
# 2    [-0.9306332129172374] -24.070438
# 3     [0.6221154083633949]  30.444129
# 4   [-0.01482913363151827]   5.159891
# 5   [-0.07449504751783644]   0.260772
# 6      [2.067716082546833]  86.773526
# 7    [-0.3979735723922431]  -5.047546
# 8     [0.2788793887294291]  22.924824
# 9   [-0.42956944026224997]  -8.901380
# 10   [-2.6111618209970433] -75.472744
# 11   [-0.1233668979327173]  13.434412
# 12    [0.2161663101238697]   0.870823
# 13    [1.5550840043960583]  50.523600
# 14   [-0.3088716559187368] -11.415188
# 15  [-0.12269649888884959]   1.880443
# 16    [1.3620319532214442]  40.505555
# 17    [0.7130857416310542]  24.993150
# 18   [-1.0651461949040768] -43.377368
# 19   [-1.2509843670867034] -47.794721

# %%
reg.coef_
# Out:
# array([62.80625486])

# %%
reg.intercept_
# Out:
# -0.007354121773842426

# %%
pyplot.scatter(X_test,y_test)
Y_plot = reg.coef_X_test.reg.Intercept_
pyplot.show()
